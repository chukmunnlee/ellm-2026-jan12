# %% [markdown]
# # IMPORTANT
#
# Run the following to install smolagents

# %%
# Imports
import os

from smolagents import CodeAgent, OpenAIServerModel
from dotenv import load_dotenv

# %%
# TODO: Import the tools notebook
# %run /content/chuk-day04-tools-blank.ipynb
# Out:
#    id      country            city   latitude  longitude  altitude
# 0   2  Afghanistan        Kandahar  31.610000  65.699997      1015
# 1   3  Afghanistan  Mazar-e Sharif  36.706944  67.112221       369
# 2   4  Afghanistan           Herat  34.340000  62.189999       927
# 3   5  Afghanistan       Jalalabad  34.420000  70.449997       573
# 4   6  Afghanistan          Konduz  36.720000  68.860001       394
# {'temperature_unit': '°C', 'temperature': 10.5}

# %%
# TODO: Get the Huggingface token
# IMPORTANT: Before you run this cell, create a file called .env in day04 directory
# and add the following line into the file
# OPENAI_API_KEY=OpenAI_API_key

loaded = load_dotenv('/content/dot_env')
print(loaded)

API_KEY = os.getenv('API_KEY')

model_name = 'gpt-5-mini-2025-08-07'
# Out:
# True

# %%
# TODO: Load an agent

# The LLM that the agent will be using
model = OpenAIServerModel(model_id = model_name, api_key=API_KEY)

# Create the agent
agent = CodeAgent(tools=[], model=model, add_base_tools=True)

# %%
# TODO: List of tools
for t in agent.tools.keys():
  print(f'tool = {t}')
# Out:
# tool = web_search
# tool = visit_webpage
# tool = final_answer

# %%
# TODO Run a simple query
question = ''

agent.run(question, max_steps=5)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What specific, generous act does Scrooge perform for the Cratchit family on Christmas morning?                  │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-5-mini-2025-08-07 ───────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   results = web_search(query="Scrooge sends turkey to Cratchit Christmas morning A Christmas Carol text Project
#   Gutenberg")
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [A Christmas Carol - Wikipedia](https://en.wikipedia.org/wiki/A_Christmas_Carol)
# ... sends a large turkey to the Cratchit home for Christmas dinner and spends the afternoon at Fred's Christmas
# party. The following day he gives Cratchit an ...
#
# [The Project Gutenberg eBook of A Christmas Carol, by Charles
# Dickens](https://www.gutenberg.org/files/46/46-h/46-h.htm)
# 4 Mar 2018 · “I'll send it to Bob Cratchit's! ... Make up the fires, and buy another coal-scuttle before you dot
# another i, Bob Cratchit!” Scrooge and Bob ...
#
# [The Project Gutenberg eBook of A Christmas Carol, by C. Z.
# Barnett.](https://www.gutenberg.org/files/41739/41739-h/41739-h.htm)
# Scrooge, the Miser, discovered near fire. Bob Cratchit, writing near desk, l. h. As the Curtain rises he descends
# from stool—approaches fire to stir it.
#
# [[EPUB] "Old Scrooge": A Christmas Carol in Five Staves. / Dramatized from
# ...](https://www.gutenberg.org/ebooks/40729.epub.noimages)
# 22 Oct 2024 · I'll send it to Bob Cratchit's. (Rubbing his hands and chuckling.) He shan't know who sent it. It's
# twice the size of Tiny Tim. Joe Miller ...
#
# [A Christmas Carol, by Charles Dickens](https://archive.org/download/achristmascarol00046gut/46-h/46-h.htm)
# “I'll send it to Bob Cratchit's! ... Make up the fires, and buy another coal-scuttle before you dot another i, Bob
# Cratchit!” Scrooge and Bob Cratchit.
#
# [Plain Text UTF-8 - Project Gutenberg](https://www.gutenberg.org/ebooks/41739.txt.utf-8)
# Tiny Tim shall not go without his Christmas dinner notwithstanding your loss--no, nor you either--nor any of your
# family, Bob Cratchit. At such a time as this, ...
#
# [Annotations: A Christmas Carol by Charles Dickens - JSTOR
# Daily](https://daily.jstor.org/annotations-a-christmas-carol-by-charles-dickens/)
# 14 Dec 2024 · “I'll send it to Bob Cratchit's!” whispered Scrooge, rubbing his hands, and splitting with a laugh.
# “He sha'n't know who sends it. It's ...
#
# [A Christmas Carol by Charles Dickens was published -
# Facebook](https://www.facebook.com/groups/StarTrekDiscovery/posts/3305028593081903/)
# 18 Dec 2022 · He sends a giant Christmas turkey to the Cratchit house and attends ... Cratchit, Scrooge's underpaid
# and overworked clerk. Scrooge ...
#
# [A Christmas Carol Text: Full Story and Analysis - Party Ideas &
# Guides](https://party.alibaba.com/christmas/a-christmas-carol-text)
# 6 days ago · Greed: The contrast between Scrooge's counting house and the warmth of the Cratchit home underscores
# the human cost of unchecked capitalism.
#
# [22 December 2023. Just Two Things Xmas
# Stocking.](https://justtwothings.substack.com/p/22-december-2023-just-two-things)
# 22 Dec 2023 · We remember (spoilers!) the final scenes of A Christmas Carol in which Scrooge sends the turkey round
# to the Cratchit's house: a turkey is a ...
#
# Out: None
# [Step 1: Duration 14.98 seconds| Input tokens: 2,090 | Output tokens: 833]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   page = visit_webpage(url="https://www.gutenberg.org/files/46/46-h/46-h.htm")
#   phrase = "I'll send it to Bob Cratchit's"
#   idx = page.find(phrase)
#   if idx != -1:
#       start = max(0, idx-200)
#       end = idx+200
#       print(page[start:end])
#   else:
#       # Fallback: print a shorter start of the page
#       print(page[:1000])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'page = visit_webpage(url="https://www.gutenberg.org/files/46/46-h/46-h.htm")' due
# to: ImportError: You must install packages `markdownify` and `requests` to run this tool: for instance run `pip
# install markdownify requests`.
# [Step 2: Duration 17.40 seconds| Input tokens: 5,094 | Output tokens: 2,026]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   answer = "He sends the Cratchit family a very large turkey for their Christmas dinner (sent anonymously)."
#   print(answer)
#   final_answer(answer)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# He sends the Cratchit family a very large turkey for their Christmas dinner (sent anonymously).
# Final answer: He sends the Cratchit family a very large turkey for their Christmas dinner (sent anonymously).
# [Step 3: Duration 10.38 seconds| Input tokens: 8,512 | Output tokens: 2,565]
# 'He sends the Cratchit family a very large turkey for their Christmas dinner (sent anonymously).'

# %%
# TODO: Create an agent with our own tools
# Create an array with a list of our tools
tools = [ get_latlng, get_temperature, SQLiteTool('/content/data/chinook_sqlite.sqlite') ]

agent = CodeAgent(tools=tools, model=model, add_base_tools=False)

# %%
for t in agent.tools.keys():
  print(t)
# Out:
# get_latlng
# get_temperature
# query_tracks
# final_answer

# %%
question = 'Name a song that is sung by Bruno Mars and Rose from Black Pink?'

agent.run(question, max_steps=10)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Name a song that is sung by Bruno Mars and Rose from Black Pink?                                                │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-5-mini-2025-08-07 ───────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   print("Do you mean a song they both have performed (a cover), or do you want one Bruno Mars song and one Rosé
#   song (two separate songs), or are you asking about a duet/collaboration?")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Do you mean a song they both have performed (a cover), or do you want one Bruno Mars song and one Rosé song (two
# separate songs), or are you asking about a duet/collaboration?
#
# Out: None
# [Step 1: Duration 13.38 seconds| Input tokens: 2,205 | Output tokens: 933]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   print("Bruno Mars: 'Just the Way You Are' — Rosé (BLACKPINK): 'On The Ground'")
#   final_answer("Bruno Mars: 'Just the Way You Are' — Rosé (BLACKPINK): 'On The Ground'")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Bruno Mars: 'Just the Way You Are' — Rosé (BLACKPINK): 'On The Ground'
# Final answer: Bruno Mars: 'Just the Way You Are' — Rosé (BLACKPINK): 'On The Ground'
# [Step 2: Duration 9.74 seconds| Input tokens: 4,710 | Output tokens: 1,552]
# "Bruno Mars: 'Just the Way You Are' — Rosé (BLACKPINK): 'On The Ground'"

# %%
# TODO: Perform task with get_latlng and get_temperature function
# TODO: Will switch to duckduckgo if cannot get the temperature from custom functions

# %%
#TODO: Rerun the query
band = "michael jackson"
# band = "men At work"
# band = 'james brown'

# %% [markdown]
# # Document loaders
#
# We will examine how to load and split popular file formats. The purpose of is to insert these documents into a vector database for semantic searches.

# %%
# Download the NLTK data
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
# Imports
import json, random
from langchain_community.document_loaders import UnstructuredEPubLoader, UnstructuredExcelLoader, UnstructuredPowerPointLoader
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader, JSONLoader, UnstructuredXMLLoader
from langchain_community.document_loaders import UnstructuredEmailLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter, RecursiveJsonSplitter

# %% [markdown]
# # Create a text splitter
#
# The purpose of splitting the text is to enable more precise search results by ensuring that each smaller segment captures relevant context within a larger document. When these text fragrments are used as context in prompts, they will not exceed the context window.

# %%
# TODO: Create a text splitter
chunk_size = 300
chunk_overlap = 20

text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

# %% [markdown]
# ## Loading and splitting documents
#
# Documents can be loaded and split either as a single or as elements eg pages, individual slides, spreadsheet, etc. Set the `mode` arguemnt to
# - `single` - load the entire document as a single object default for most loaders
# - `multi`, `elements` - split the document into their respective elements eg pages, slides, etc.

# %%
def print_chunk_info(chunks):
   print(f'No of chunks: {len(chunks)}')
   idx = random.randrange(0, len(chunks))
   print(f'Chunk index: {idx}')
   print('Chunk details')
   for k, v in enumerate(chunks[idx]):
      print(f'\t{k} = {v}')

# %%
# TODO: Word doucment
# Load the document
word_loader = Docx2txtLoader(file_path="/content/docs/SST RL Python Setup.docx")

# chunk the doc
chunks = word_loader.load_and_split(text_splitter)

print_chunk_info(chunks)
# Out:
# No of chunks: 12
# Chunk index: 8
# Chunk details
# 	0 = ('id', None)
# 	1 = ('metadata', {'source': '/content/docs/SST RL Python Setup.docx'})
# 	2 = ('page_content', 'After you have installed VSC, launch it. Next, we need to install the Python Extension for VSC. Open the extension panel by clicking on this icon  on the menu along VSC’s left window edge. Type Python on the extension window and select the Microsoft Python Extension. See the following image')
# 	3 = ('type', 'Document')

# %%
# TODO: Excel doucment

# Load as a single document
xls_loader = UnstructuredExcelLoader(file_path="/content/docs/Financial Sample.xlsx", mode="single")
chunks = xls_loader.load_and_split(text_splitter)

print_chunk_info(chunks)


# "text_as_html" key in the document metadata.
xls_loader = UnstructuredExcelLoader(file_path="/content/docs/Financial Sample.xlsx", mode="elements")
chunks = xls_loader.load_and_split(text_splitter)

print('============ element')
print_chunk_info(chunks)
# Out:
# No of chunks: 287
# Chunk index: 161
# Chunk details
# 	0 = ('id', None)
# 	1 = ('metadata', {'source': '/content/docs/Financial Sample.xlsx'})
# 	2 = ('page_content', '2014 Government United States of America Amarilla Medium 2907 260 7 20349 1627.92 18721.08 14535 4186.08 2014-06-01 00:00:00 6 June 2014 Government Germany Amarilla Medium 1366 260 20 27320 2185.6 25134.4 13660 11474.4 2014-06-01 00:00:00 6 June 2014 Small Business Mexico Amarilla Medium 2460 260')
# 	3 = ('type', 'Document')
# ============ element
# No of chunks: 287
# Chunk index: 62
# Chunk details
# 	0 = ('id', None)
# 	1 = ('metadata', {'source': '/content/docs/Financial Sample.xlsx', 'file_directory': '/content/docs', 'filename': 'Financial Sample.xlsx', 'last_modified': '2025-02-28T03:53:21', 'page_name': 'Sheet1', 'page_number': 1, 'text_as_html': '<table><tr><td>Segment</td><td>Country</td><td>Product</td><td>Discount Band</td><td>Units Sold</td><td>Manufacturing Price</td><td>Sale Price</td><td>Gross Sales</td><td>Discounts</td><td>Sales</td><td>COGS</td><td>Profit</td><td>Date</td><td>Month Number</td><td>Month Name</td><td>Year</td></tr><tr><td>Government</td><td>Canada</td><td>Carretera</td><td/><td>1618.5</td><td>3</td><td>20</td><td>32370</td><td>0</td><td>32370</td><td>16185</td><td>16185</td><td>2014-01-01 00:00:00</td><td>1</td><td>January</td><td>2014</td></tr><tr><td>Government</td><td>Germany</td><td>Carretera</td><td/><td>1321</td><td>3</td><td>20</td><td>26420</td><td>0</td><td>26420</td><td>13210</td><td>13210</td><td>2014-01-01 00:00:00</td><td>1</td><td>January</td><td>2014</td></tr><tr><td>Midmarket</td><td>France</td><td>Carretera</td><td/><td>2178</td><td>3</td><td>15</td><td>32670</td><td>0</td><td>32670</td><td>21780</td><td>10890</td><td>2014-06-01 00:00:00</td><td>6</td><td>June</td><td>2014</td></tr><tr><td>Midmarket</td><td>Germany</td><td>Carretera</td><td/><td>888</td><td>3</td><td>15</td><td>13320</td><td>0</td><td>13320</td><td>8880</td><td>4440</td><td>2014-06-01 00:00:00</td><td>6</td><td>June</td><td>2014</td></tr><tr><td>Midmarket</td><td>Mexico</td><td>Carretera</td><td/><td>2470</td><td>3</td><td>15</td><td>37050</td><td>0</td><td>37050</td><td>24700</td><td>12350</td><td>2014-06-01 00:00:00</td><td>6</td><td>June</td><td>2014</td></tr><tr><td>Government</td><td>Germany</td><td>Carretera</td><td/><td>1513</td><td>3</td><td>350</td><td>529550</td><td>0</td><td>529550</td><td>393380</td><td>136170</td><td>2014-12-01 00:00:00</td><td>12</td><td>December</td><td>2014</td></tr><tr><td>Midmarket</td><td>Germany</td><td>Montana</td><td/><td>921</td><td>5</td><td>15</td><td>13815</td><td>0</td><td>13815</td><td>9210</td><td>4605</td><td>2014-03-01 00:00:00</td><td>3</td><td>March</td><td>2014</td></tr><tr><td>Channel Partners</td><td>Canada</td><td>Montana</td><td/><td>2518</td><td>5</td><td>12</td><td>30216</td><td>0</td><td>30216</td><td>7554</td><td>22662</td><td>2014-06-01 00:00:00</td><td>6</td><td>June</td><td>2014</td></tr><tr><td>Government</td><td>France</td><td>Montana</td><td/><td>1899</td><td>5</td><td>20</td><td>37980</td><td>0</td><td>37980</td><td>18990</td><td>18990</td><td>2014-06-01 00:00:00</td><td>6</td><td>June</td><td>2014</td></tr><tr><td>Channel Partners</td><td>Germany</td><td>Montana</td><td/><td>1545</td><td>5</td><td>12</td><td>18540</td><td>0</td><td>18540</td><td>4635</td><td>13905</td><td>2014-06-01 00:00:00</td><td>6</td><td>June</td><td>2014</td></tr><tr><td>Midmarket</td><td>Mexico</td><td>Montana</td><td/><td>2470</td><td>5</td><td>15</td><td>37050</td><td>0</td><td>37050</td><td>24700</td><td>12350</td><td>2014-06-01 00:00:00</td><td>6</td><td>June</td><td>2014</td></tr><tr><td>Enterprise</td><td>Canada</td><td>Montana</td><td/><td>2665.5</td><td>5</td><td>125</td><td>333187.5</td><td>0</td><td>333187.5</td><td>319860</td><td>13327.5</td><td>2014-07-01 00:00:00</td><td>7</td><td>July</td><td>2014</td></tr><tr><td>Small Business</td><td>Mexico</td><td>Montana</td><td/><td>958</td><td>5</td><td>300</td><td>287400</td><td>0</td><td>287400</td><td>239500</td><td>47900</td><td>2014-08-01 00:00:00</td><td>8</td><td>August</td><td>2014</td></tr><tr><td>Government</td><td>Germany</td><td>Montana</td><td/><td>2146</td><td>5</td><td>7</td><td>15022</td><td>0</td><td>15022</td><td>10730</td><td>4292</td><td>2014-09-01 00:00:00</td><td>9</td><td>September</td><td>2014</td></tr><tr><td>Enterprise</td><td>Canada</td><td>Montana</td><td/><td>345</td><td>5</td><td>125</td><td>43125</td><td>0</td><td>43125</td><td>41400</td><td>1725</td><td>2013-10-01 00:00:00</td><td>10</td><td>October</td ...
# 	2 = ('page_content', '99814.5 2014-01-01 00:00:00 1 January 2014 Enterprise Canada Paseo Low 1774 10 125 221750 6652.5 215097.5 212880 2217.5 2014-03-01 00:00:00 3 March 2014 Channel Partners France Paseo Low 1901 10 12 22812 684.36 22127.64 5703 16424.64 2014-06-01 00:00:00 6 June 2014 Small Business Germany Paseo Low')
# 	3 = ('type', 'Document')

# %%
# TODO: Load Powerpoint

# %%
# TODO: Load Email

# %%
# TODO: Load PDF
pdf_loader = PyPDFLoader(file_path="/content/docs/Path-to-GitOps-Red-Hat-Developer-e-book.pdf")

chunks = pdf_loader.load_and_split(text_splitter)

print_chunk_info(chunks)
# Out:
# No of chunks: 404
# Chunk index: 398
# Chunk details
# 	0 = ('id', None)
# 	1 = ('metadata', {'producer': 'Adobe PDF Library 10.0.1', 'creator': 'Adobe InDesign CS6 (Macintosh)', 'creationdate': '2022-07-15T19:22:48-05:00', 'moddate': '2022-07-17T10:32:28-04:00', 'title': 'The Path to GitOps', 'source': '/content/docs/Path-to-GitOps-Red-Hat-Developer-e-book.pdf', 'total_pages': 45, 'page': 43, 'page_label': '44'})
# 	2 = ('page_content', 'References\n[8.1]  https:/ /www.redhat.com/ en/technologies/management/advanced-cluster-\nmanagement\n[8.2] https:/ / open-cluster-management.io/\n[8.3] https:/ / developers.redhat.com/products/ansible/ overview\n[8.4] https:/ /www.redhat.com/ en/about/videos/acm-ansible-integration-overview')
# 	3 = ('type', 'Document')

# %%
# TODO: Load EPUB

# %% [markdown]
# ## Processing structured document/JSON

# %%
# TODO: Create a JSON splitter
json_splitter = RecursiveJsonSplitter(max_chunk_size=64)

# %%
# TODO: Process a single JSON object
with open('/content/docs/single.json') as f:
  json_data = json.load(f)

chunks = json_splitter.split_json(json_data=json_data)

print_chunk_info(chunks)
print(chunks[5])
# Out:
# No of chunks: 8
# Chunk index: 7
# Chunk details
# 	0 = web-app
# {'web-app': {'servlet-mapping': {'cofaxTools': '/tools/*'}}}

# %%
# TODO: Process an array of JSON objects, return chunks as Dictionary

with open('/content/docs/tv-shows.json') as f:
   json_data = json.load(f)

chunks = json_splitter.split_json(json_data=json_data, convert_lists=True)
print(chunks)
# Out:
# [{'0': {'id': 1, 'url': 'http://www.tvmaze.com/shows/1/under-the-dome'}}, {'0': {'name': 'Under the Dome', 'type': 'Scripted'}}, {'0': {'language': 'English', 'genres': {'0': 'Drama'}}}, {'0': {'genres': {'1': 'Science-Fiction', '2': 'Thriller'}}}, {'0': {'status': 'Ended', 'runtime': 60, 'premiered': '2013-06-24'}}, {'0': {'officialSite': 'http://www.cbs.com/shows/under-the-dome/'}}, {'0': {'schedule': {'time': '22:00', 'days': {'0': 'Thursday'}}}}, {'0': {'rating': {'average': 6.5}, 'weight': 91, 'network': {'id': 2}}}, {'0': {'network': {'name': 'CBS', 'country': {'name': 'United States'}}}}, {'0': {'network': {'country': {'code': 'US', 'timezone': 'America/New_York'}}}}, {'0': {'webChannel': None, 'externals': {'tvrage': 25988}}}, {'0': {'externals': {'thetvdb': 264492, 'imdb': 'tt1553656'}}}, {'0': {'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1.jpg'}}}, {'0': {'image': {'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1.jpg'}}}, {'0': {'summary': "<p><b>Under the Dome</b> is the story of a small town that is suddenly and inexplicably sealed off from the rest of the world by an enormous transparent dome. The town's inhabitants must deal with surviving the post-apocalyptic conditions while searching for answers about the dome, where it came from and if and when it will go away.</p>"}}, {'0': {'updated': 1529612668, '_links': {'self': {'href': 'http://api.tvmaze.com/shows/1'}}}}, {'0': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/185054'}}}}, {'1': {'id': 2, 'url': 'http://www.tvmaze.com/shows/2/person-of-interest'}}, {'1': {'name': 'Person of Interest', 'type': 'Scripted'}}, {'1': {'language': 'English', 'genres': {'0': 'Drama'}}}, {'1': {'genres': {'1': 'Action', '2': 'Crime'}, 'status': 'Ended'}}, {'1': {'runtime': 60, 'premiered': '2011-09-22', 'officialSite': 'http://www.cbs.com/shows/person_of_interest/'}}, {'1': {'schedule': {'time': '22:00', 'days': {'0': 'Tuesday'}}}}, {'1': {'rating': {'average': 9}, 'weight': 96, 'network': {'id': 2}}}, {'1': {'network': {'name': 'CBS', 'country': {'name': 'United States'}}}}, {'1': {'network': {'country': {'code': 'US', 'timezone': 'America/New_York'}}}}, {'1': {'webChannel': None, 'externals': {'tvrage': 28376}}}, {'1': {'externals': {'thetvdb': 248742, 'imdb': 'tt1839578'}}}, {'1': {'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/163/407679.jpg'}}}, {'1': {'image': {'original': 'http://static.tvmaze.com/uploads/images/original_untouched/163/407679.jpg'}}}, {'1': {'summary': '<p>You are being watched. The government has a secret system, a machine that spies on you every hour of every day. I know because I built it. I designed the Machine to detect acts of terror but it sees everything. Violent crimes involving ordinary people. People like you. Crimes the government considered "irrelevant". They wouldn\'t act so I decided I would. But I needed a partner. Someone with the skills to intervene. Hunted by the authorities, we work in secret. You\'ll never find us. But victim or perpetrator, if your number is up, we\'ll find you.</p>'}}, {'1': {'updated': 1535507028, '_links': {'self': {'href': 'http://api.tvmaze.com/shows/2'}}}}, {'1': {'_links': {'previousepisode': {'href': 'http://api.tvmaze.com/episodes/659372'}}}}, {'2': {'id': 3, 'url': 'http://www.tvmaze.com/shows/3/bitten'}}, {'2': {'name': 'Bitten', 'type': 'Scripted', 'language': 'English'}}, {'2': {'genres': {'0': 'Drama', '1': 'Horror', '2': 'Romance'}}}, {'2': {'status': 'Ended', 'runtime': 60, 'premiered': '2014-01-11'}}, {'2': {'officialSite': 'http://bitten.space.ca/'}}, {'2': {'schedule': {'time': '22:00', 'days': {'0': 'Friday'}}}}, {'2': {'rating': {'average': 7.6}, 'weight': 75, 'network': {'id': 7}}}, {'2': {'network': {'name': 'Space', 'country': {'name': 'Canada'}}}}, {'2': {'network': {'country': {'code': 'CA', 'timezone': 'America/Halifax'}}}}, {'2': {'webChannel': None, 'externals': {'tvrage': 34 ...

# %%
# TODO: Process an array of JSON objects, return chunks as Document

with open('/content/docs/tv-shows.json') as f:
   json_data = json.load(f)

chunks = json_splitter.create_documents(texts=json_data)

print(chunks)
# Out:
# [Document(metadata={}, page_content='{"id": 1, "url": "http://www.tvmaze.com/shows/1/under-the-dome"}'), Document(metadata={}, page_content='{"name": "Under the Dome", "type": "Scripted", "language": "English"}'), Document(metadata={}, page_content='{"genres": ["Drama", "Science-Fiction", "Thriller"]}'), Document(metadata={}, page_content='{"status": "Ended", "runtime": 60, "premiered": "2013-06-24"}'), Document(metadata={}, page_content='{"officialSite": "http://www.cbs.com/shows/under-the-dome/"}'), Document(metadata={}, page_content='{"schedule": {"time": "22:00", "days": ["Thursday"]}}'), Document(metadata={}, page_content='{"rating": {"average": 6.5}, "weight": 91, "network": {"id": 2}}'), Document(metadata={}, page_content='{"network": {"name": "CBS", "country": {"name": "United States"}}}'), Document(metadata={}, page_content='{"network": {"country": {"code": "US", "timezone": "America/New_York"}}}'), Document(metadata={}, page_content='{"webChannel": null, "externals": {"tvrage": 25988}}'), Document(metadata={}, page_content='{"externals": {"thetvdb": 264492, "imdb": "tt1553656"}}'), Document(metadata={}, page_content='{"image": {"medium": "http://static.tvmaze.com/uploads/images/medium_portrait/0/1.jpg"}}'), Document(metadata={}, page_content='{"image": {"original": "http://static.tvmaze.com/uploads/images/original_untouched/0/1.jpg"}}'), Document(metadata={}, page_content='{"summary": "<p><b>Under the Dome</b> is the story of a small town that is suddenly and inexplicably sealed off from the rest of the world by an enormous transparent dome. The town\'s inhabitants must deal with surviving the post-apocalyptic conditions while searching for answers about the dome, where it came from and if and when it will go away.</p>"}'), Document(metadata={}, page_content='{"updated": 1529612668, "_links": {"self": {"href": "http://api.tvmaze.com/shows/1"}}}'), Document(metadata={}, page_content='{"_links": {"previousepisode": {"href": "http://api.tvmaze.com/episodes/185054"}}}'), Document(metadata={}, page_content='{"id": 2, "url": "http://www.tvmaze.com/shows/2/person-of-interest"}'), Document(metadata={}, page_content='{"name": "Person of Interest", "type": "Scripted"}'), Document(metadata={}, page_content='{"language": "English", "genres": ["Drama", "Action", "Crime"]}'), Document(metadata={}, page_content='{"status": "Ended", "runtime": 60, "premiered": "2011-09-22"}'), Document(metadata={}, page_content='{"officialSite": "http://www.cbs.com/shows/person_of_interest/"}'), Document(metadata={}, page_content='{"schedule": {"time": "22:00", "days": ["Tuesday"]}}'), Document(metadata={}, page_content='{"rating": {"average": 9}, "weight": 96, "network": {"id": 2}}'), Document(metadata={}, page_content='{"network": {"name": "CBS", "country": {"name": "United States"}}}'), Document(metadata={}, page_content='{"network": {"country": {"code": "US", "timezone": "America/New_York"}}}'), Document(metadata={}, page_content='{"webChannel": null, "externals": {"tvrage": 28376}}'), Document(metadata={}, page_content='{"externals": {"thetvdb": 248742, "imdb": "tt1839578"}}'), Document(metadata={}, page_content='{"image": {"medium": "http://static.tvmaze.com/uploads/images/medium_portrait/163/407679.jpg"}}'), Document(metadata={}, page_content='{"image": {"original": "http://static.tvmaze.com/uploads/images/original_untouched/163/407679.jpg"}}'), Document(metadata={}, page_content='{"summary": "<p>You are being watched. The government has a secret system, a machine that spies on you every hour of every day. I know because I built it. I designed the Machine to detect acts of terror but it sees everything. Violent crimes involving ordinary people. People like you. Crimes the government considered \\"irrelevant\\". They wouldn\'t act so I decided I would. But I needed a partner. Someone with the skills to intervene. Hunted by the authorities, we work in secret. You\'ll never find us. But victim or perpetrator, if your number is up, we\'ll find yo ...

# %%
# TODO: Extract specific attributes from the JSON document, use JSON path to define which element
json_loader = JSONLoader(
    file_path='/content/docs/tv-shows.json',
    jq_schema='.[].summary',
    text_content=True
)

chunks = json_loader.load()
#chunks = json_loader.load_and_split(text_splitter)

print_chunk_info(chunks)
# Out:
# No of chunks: 240
# Chunk index: 73
# Chunk details
# 	0 = ('id', None)
# 	1 = ('metadata', {'source': '/content/docs/tv-shows.json', 'seq_num': 74})
# 	2 = ('page_content', '<p><b>Sons of Anarchy</b> is an American television drama series created by Kurt Sutter, about the lives of a close-knit outlaw motorcycle club operating in Charming, a fictional town in California\'s Central Valley. The show centers on protagonist Jackson "Jax" Teller (Charlie Hunnam), initially the vice president of the club, who begins questioning the club and himself.</p>')
# 	3 = ('type', 'Document')
